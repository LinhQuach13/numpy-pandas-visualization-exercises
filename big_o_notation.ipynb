# %% [markdown]
# 5. Make a new Jupyter notebook named big_o_notation.ipynb
#
# - Title your chart "Big O Notation"
# - Label your x axis "Elements"
# - Label your y axis "Operations"
# - Label your curves or make a legend for the curves
# - Use LaTex notation where possible
# - Curves to graph
#
# - y=0n+1 and label the curve "O(1)"
# - y=log(n)and label the curve "O(log n)"
# - y=n and label the curve "O(n)"
# - y=n∗log(n)and label it "O(n log n)"
# - y=n**2 and label it "O(n^2)"
# - y=2n and label it "O(2^n)"
# - y=n! and label it "O(n!)"
# - y=n**n and label it "O(n^n)"

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
plt.figure(figsize = (10, 8))

plt.title('Big O Notation', fontsize = 16)
plt.xlabel('Elements')
plt.ylabel('Operations')

n = np.array([1,2,3,4,5])
y = 0*n+1
plt.plot(n, y, c='black', marker= "p", ls=':', label='$O(1)$')

n = np.array([1,2,3,4,5])
y2 = [math.log(x) for x in n]
plt.plot(n, y2, c='darkmagenta', marker= "s", label='$O(log n)$')


n = np.array([1,2,3,4,5])
y3 = n
plt.plot(n, y3, c='cyan', marker= "v", label='$O(n)$')


n = np.array([1,2,3,4,5])
y4 = [x* math.log(x) for x in n]
plt.plot(n, y4, c='red', marker='*', label='$O(n log n)$')


n = np.array([1,2,3,4,5])
y5 = n**2
plt.plot(n, y5, c='mediumaquamarine', label='$O(n^2)$')


n = np.array([1,2,3,4,5])
y6 =2*n
plt.plot(n, y6, c='sandybrown', ls=':', label='$O(2*n)$')

n= np.array([1,2,3,4,5])
y7 = [math.factorial(x) for x in n]
plt.plot(n, y7, c='deeppink', label='$O(n!)$')


n = np.array([1,2,3,4,5])
y8 = n**n 
plt.plot(n, y8, c='darkslategray', label='$O(n^n)$')


plt.xlim(0, 6)
plt.ylim(0, 40)
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# - Bonus
#
#    - 6. Write the code necessary to write your name on a chart. Use box letters.

# %%
#Write the code necessary to write your name on a chart. Use box letters.

plt.figure(figsize = (10,6))

#L
x1=[1,1]
y1=[1,2.5]
x2=[1, 1.2]
y2=[1,1]


#I
x3=[1.25,1.25]
y3=[1,2]

#. over I
x4=[1.25,1.25]
y4=[2.3,2.3]


#N
x5=[1.3,1.3]
y5=[1, 2.5]

x6=[1.3, 1.4]
y6=[2.5,1]

x7=[1.4,1.4]
y7=[1,2.5]


#H
x8=[1.45,1.45]
y8=[1,2.5]

x9=[1.45,1.6]
y9=[1.8,1.8]

x10=[1.6,1.6]
y10=[1,2.5]


plt.plot(x1,y1, linewidth= 8, c= 'magenta')
plt.plot(x2,y2, linewidth= 8, c= 'magenta')
plt.plot(x3,y3, linewidth= 8, c= 'cyan')
plt.scatter(x4,y4, linewidth= 2, c= 'cyan', s=300)
plt.plot(x5,y5, linewidth= 8, c= 'deeppink')
plt.plot(x6,y6, linewidth= 8, c= 'deeppink')
plt.plot(x7,y7, linewidth= 8, c= 'deeppink')
plt.plot(x8,y8, linewidth= 8, c= 'royalblue')
plt.plot(x9,y9, linewidth= 8, c= 'royalblue')
plt.plot(x10,y10, linewidth= 8, c= 'royalblue')


plt.show()
