# %% [markdown]
# # Exercises

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import math

# %% [markdown]
# 1. Use matplotlib to plot the following equation:
#
# y =x**2 −x+2
#
# - You'll need to write the code that generates the x and y points.
#
# - Add an anotation for the point 0, 0, the origin.

# %%
n = np.linspace(-20, 20, 50)
z = n**2 - n + 2  

plt.plot(n, z)

plt.annotate('Intersection', xy=(0, 0), xytext=(-12, 45),
             arrowprops={'facecolor': 'blue'})

plt.show()

# %% [markdown]
# 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):

# %% [markdown]
# - y=√x
#
# - You can use functions from the math module to help implement some of the equations above.

# %%
x = np.linspace(0, 20, 50)
fig = plt.figure(figsize = (6, 4))
y1 = x**(0.5)

plt.plot(x, y1)

plt.show()

# %% [markdown]
# y=x**3

# %%
x = np.linspace(0, 20, 50)
fig = plt.figure(figsize = (6, 4))
y2 = x**3

plt.plot(x, y2)

plt.show()

# %% [markdown]
# y=2**x

# %%
x = x = np.linspace(0, 20, 50)
fig = plt.figure(figsize = (6, 4))
  
y3 = 2**x
plt.plot(x, y3)

plt.show()

# %% [markdown]
# y=1/(x+1)

# %%
x = np.linspace(0, 20, 50)
fig = plt.figure(figsize = (6, 4))
  
y4 = 1/(x+1)
plt.plot(x, y4)

plt.show()

# %% [markdown]
# 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
n_rows= 2
n_cols= 2


x = np.linspace(0, 20, 50)
y1 = x**(0.5)
fig = plt.figure(figsize = (6, 4))
plt.subplot(n_rows, n_cols, 1)
plt.plot(x, y1, c='black')
plt.title('√x')

x = np.linspace(0, 20, 50)
y2 = x**3
fig = plt.figure(figsize = (6, 4))
plt.subplot(n_rows, n_cols, 2)
plt.plot(x, y2, c='green')
plt.title('x^3')


x = np.linspace(0, 20, 50)
y3 = 2**x
fig = plt.figure(figsize = (6, 4))
plt.subplot(n_rows, n_cols, 3)
plt.plot(x, y3, c= 'pink')
plt.title('2^x')


x = np.linspace(0, 20, 50)
y4 = 1/(x+1)
fig = plt.figure(figsize = (6, 5))
plt.subplot(n_rows, n_cols, 4)
plt.plot(x, y4)
plt.title('1/(x+1)')

plt.subplots_adjust(left=None, 
                bottom=0.1, 
                right=None, 
                top=None, 
                wspace=None,
                hspace=None)

plt.tight_layout()

plt.show()

# %% [markdown]
# 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
plt.figure(figsize=(6, 4))
x = np.linspace(0, 20, 50)

y1 = x**(0.5)
plt.plot(x, y1, marker = 'h', c='black', label='$√x$')


y2 = x**3
plt.plot(x, y2, c='green')
plt.plot(x, y2, marker = '.', c='fuchsia', label='$x^3$')

y3 = 2**x
plt.plot(x, y3, marker = 'v',  c= 'pink')
plt.plot(x, y3, c='green', label='$2^x$')



y4 = 1/(x+1)
plt.plot(x, y4)
plt.plot(x, y4, marker = '*', c='cyan', label='$1/(x+1)$')


plt.xlim(0,20)
plt.ylim(0,15)
plt.title('Combined Plots', fontsize = 16)
plt.legend(loc='upper right')



plt.show()
